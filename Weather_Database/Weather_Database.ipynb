# %%
# Import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import time

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform( low = -90.000, high = 90.000, size = 2000)
lngs = np.random.uniform( low = -180.000, high = 180.000, size = 2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
from citipy import citipy 

# Create a list to hold the cities
cities = []

# Use for loop to identify nearest city for each lat and longatude combo
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    
    # If the city is unique, then we add it to cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm total (1500) 
len(cities)
# Out:
# 761

# %%
# import requests module
import requests

#import API key
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call
url = 'http://api.openweathermap.org/data/2.5/weather?units=metric&APPID=' + weather_api_key

# %%
# Create an empty list to hold the weather data
city_data = []

# Print the beginning of the logging
print("Beginning Data Retrieval        ")
print('--------------------------------')


# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list

for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers and the city.
    print(f'Processing Record {record_count} of Set {set_count} | {city}')
    
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_description = city_weather['weather'][0]['description']
        
        # Append the city info into city_data list.
        
        city_data.append({'City': city.title(),
                        'Lat': city_lat,
                        'Lng': city_lng,
                        'Max Temp': city_max_temp,
                        'Humidity': city_humidity,
                        'Cloudiness': city_clouds,
                        'Wind Speed': city_wind,
                        'Country': city_country,
                        'Current Description': city_description})
# If an error is experienced, skip the city.
    except:
        
        print('City not found. Skipping...')
        
        pass

# Indicate that Data loading is complete

print('----------------------------------')
print('Date Retrival Complete            ')
print('----------------------------------')
# Out:
# Beginning Data Retrieval
# --------------------------------
# Processing Record 1 of Set 1 | bluff
# Processing Record 2 of Set 1 | juneau
# Processing Record 3 of Set 1 | saint george
# Processing Record 4 of Set 1 | punta arenas
# Processing Record 5 of Set 1 | geraldton
# Processing Record 6 of Set 1 | kruisfontein
# Processing Record 7 of Set 1 | mataura
# Processing Record 8 of Set 1 | tuktoyaktuk
# Processing Record 9 of Set 1 | albany
# Processing Record 10 of Set 1 | jamestown
# Processing Record 11 of Set 1 | saskylakh
# Processing Record 12 of Set 1 | ipua
# Processing Record 13 of Set 1 | san martin
# Processing Record 14 of Set 1 | iqaluit
# Processing Record 15 of Set 1 | akdagmadeni
# Processing Record 16 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 17 of Set 1 | lorengau
# Processing Record 18 of Set 1 | itacare
# Processing Record 19 of Set 1 | bethel
# Processing Record 20 of Set 1 | yellowknife
# Processing Record 21 of Set 1 | east london
# Processing Record 22 of Set 1 | chengde
# Processing Record 23 of Set 1 | rikitea
# Processing Record 24 of Set 1 | vanimo
# Processing Record 25 of Set 1 | qui nhon
# Processing Record 26 of Set 1 | severo-kurilsk
# Processing Record 27 of Set 1 | asfi
# Processing Record 28 of Set 1 | victoria
# Processing Record 29 of Set 1 | hermanus
# Processing Record 30 of Set 1 | victoria point
# Processing Record 31 of Set 1 | puerto ayora
# Processing Record 32 of Set 1 | xam nua
# Processing Record 33 of Set 1 | bambous virieux
# Processing Record 34 of Set 1 | aljezur
# Processing Record 35 of Set 1 | ushuaia
# Processing Record 36 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 37 of Set 1 | kaitangata
# Processing Record 38 of Set 1 | berlevag
# Processing Record 39 of Set 1 | porto walter
# Processing Record 40 of Set 1 | reforma
# Processing Record 41 of Set 1 | chokurdakh
# Processing Record 42 of Set 1 | atuona
# Processing Record 43 of Set 1 | weihe
# Processing Record 44 of Set 1 | trinidad
# Processing Record 45 of Set 1 | constitucion
# Processing Record 46 of Set 1 | ribeira grande
# Processing Record 47 of Set 1 | union
# Processing Record 48 of Set 1 | anadyr
# Processing Record 49 of Set 1 | biak
# Processing Record 50 of Set 1 | tingi
# Processing Record 1 of Set 2 | kysyl-syr
# Processing Record 2 of Set 2 | pangody
# Processing Record 3 of Set 2 | tatarsk
# Processing Record 4 of Set 2 | itaituba
# Processing Record 5 of Set 2 | wegrow
# Processing Record 6 of Set 2 | omsukchan
# Processing Record 7 of Set 2 | arraial do cabo
# Processing Record 8 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 9 of Set 2 | vestmanna
# Processing Record 10 of Set 2 | barrow
# Processing Record 11 of Set 2 | esil
# Processing Record 12 of Set 2 | nyzhnya duvanka
# Processing Record 13 of Set 2 | busselton
# Processing Record 14 of Set 2 | karratha
# Processing Record 15 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 16 of Set 2 | mitchell
# Processing Record 17 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 18 of Set 2 | deh rawud
# City not found. Skipping...
# Processing Record 19 of Set 2 | benguela
# Processing Record 20 of Set 2 | ambatofinandrahana
# Processing Record 21 of Set 2 | khuzhir
# Processing Record 22 of Set 2 | sao filipe
# Processing Record 23 of Set 2 | acapulco
# Processing Record 24 of Set 2 | kohlu
# Processing Record 25 of Set 2 | manzhouli
# Processing Record 26 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 27 of Set 2 | ponta do sol
# Processing Record 28 of Set 2 | kiama
# Processing Record 29 of Set 2 | zeya
# Processing Record 30 of Set 2 | jhang
# Processing Record 31 of Set 2 | hobart
# Processing Record 32 of Set 2 | tuatapere
# Processing Record 33 of Set 2 | ambilobe
# Processing Record 34 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 35 of Set 2 | heliconia
# Processing Record 36 of Set 2 | vaini
# Processing Record 37 of Set 2 | rodionovo-nesvetayskaya
# Processing Record 38 of Set 2 | gujar khan
# Processing Record 39 of Set 2 | hithadhoo
# Processing Record 40 of Set 2 | cape town
# Processing Record 41 of Set 2 | biga
# Processing Record 42 of Set 2 | imbituba
# Processing Record 43 of Set 2 | salalah
# Processing Record 44 of Set 2 | nhulunbuy
# Processing Record 45 of Set 2 | zheleznodorozhnyy
# Processing Record 46 of Set 2 | muli
# Processing Record 47 of Set 2 | laguna
# Processing Record 48 of Set 2 | muros
# Processing Record 49 of Set 2 | kapaa
# Processing Record 50 of Set 2 | san quintin
# Processing Record 1 of Set 3 | meulaboh
# Processing Record 2 of Set 3 | georgetown
# Processing Record 3 of Set 3 | clyde river
# Processing Record 4 of Set 3 | codrington
# Processing Record 5 of Set 3 | surin
# Processing Record 6 of Set 3 | a
# City not found. Skipping...
# Processing Record 7 of Set 3 | savonlinna
# Processing Record 8 of Set 3 | ostrovnoy
# Processing Record 9 of Set 3 | sumbe
# Processing Record 10 of Set 3 | mahebourg
# Processing Record 11 of Set 3 | bredasdorp
# Processing Record 12 of Set 3 | muravlenko
# Processing Record 13 of Set 3 | vardo
# Processing Record 14 of Set 3 | marsh harbour
# Processing Record 15 of Set 3 | butaritari
# Processing Record 16 of Set 3 | auki
# Processing Record 17 of Set 3 | dikson
# Processing Record 18 of Set 3 | yushan
# Processing Record 19 of Set 3 | vrangel
# Processing Record 20 of Set 3 | ilulissat
# Processing Record 21 of Set 3 | torbay
# Processing Record 22 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 23 of Set 3 | canals
# Processing Record 24 of Set 3 | port lincoln
# Processing Record 25 of Set 3 | maraba
# Processing Record 26 of Set 3 | byron bay
# Processing Record 27 of Set 3 | pacific grove
# Processing Record 28 of Set 3 | huarmey
# Processing Record 29 of Set 3 | qaanaaq
# Processing Record 30 of Set 3 | klyuchi
# Processing Record 31 of Set 3 | taltal
# Processing Record 32 of Set 3 | provideniya
# Processing Record 33 of Set 3 | new norfolk
# Processing Record 34 of Set 3 | udachnyy
# Processing Record 35 of Set 3 | salug
# Processing Record 36 of Set 3 | umm bab
# Processing Record 37 of Set 3 | paamiut
# Processing Record 38 of Set 3 | sambava
# Processing Record 39 of Set 3 | tiksi
# Processing Record 40 of Set 3 | kodiak
# Processing Record 41 of Set 3 | bacuit
# City not found. Skipping...
# Processing Record 42 of Set 3 | pevek
# Processing Record 43 of Set 3 | saint-francois
# Processing Record 44 of Set 3 | ancud
# Processing Record 45 of Set 3 | flinders
# Processing Record 46 of Set 3 | san patricio
# Processing Record 47 of Set 3 | caravelas
# Processing Record 48 of Set 3 | sakakah
# Processing Record 49 of Set 3 | tomatlan
# Processing Record 50 of Set 3 | oxford
# Processing Record 1 of Set 4 | saint-georges
# Processing Record 2 of Set 4 | castro
# Processing Record 3 of Set 4 | champerico
# Processing Record 4 of Set 4 | thompson
# Processing Record 5 of Set 4 | tasiilaq
# Processing Record 6 of Set 4 | bubaque
# Processing Record 7 of Set 4 | coihaique
# Processing Record 8 of Set 4 | nabire
# Processing Record 9 of Set 4 | san vicente
# Processing Record 10 of Set 4 | movileni
# Processing Record 11 of Set 4 | vila velha
# Processing Record 12 of Set 4 | nikolskoye
# Processing Record 13 of Set 4 | palafrugell
# Processing Record 14 of Set 4 | ballina
# Processing Record 15 of Set 4 | sahuaripa
# Processing Record 16 of Set 4 | santa isabel do rio negro
# Processing Record 17 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 18 of Set 4 | luganville
# Processing Record 19 of Set 4 | karoi
# Processing Record 20 of Set 4 | namibe
# Processing Record 21 of Set 4 | balkanabat
# Processing Record 22 of Set 4 | krasnoselkup
# Processing Record 23 of Set 4 | kuantan
# Processing Record 24 of Set 4 | monticello
# Processing Record 25 of Set 4 | avarua
# Processing Record 26 of Set 4 | avera
# Processing Record 27 of Set 4 | lebu
# Processing Record 28 of Set 4 | khatanga
# Processing Record 29 of Set 4 | itapetinga
# Processing Record 30 of Set 4 | chapais
# Processing Record 31 of Set 4 | marathopolis
# City not found. Skipping...
# Processing Record 32 of Set 4 | kununurra
# Processing Record 33 of Set 4 | yangambi
# Processing Record 34 of Set 4 | cananea
# Processing Record 35 of Set 4 | port augusta
# Processing Record 36 of Set 4 | tarudant
# City not found. Skipping...
# Processing Record 37 of Set 4 | longyearbyen
# Processing Record 38 of Set 4 | mar del plata
# Processing Record 39 of Set 4 | bilibino
# Processing Record 40 of Set 4 | neiafu
# Processing Record 41 of Set 4 | placerville
# Processing Record 42 of Set 4 | abay
# Processing Record 43 of Set 4 | hasaki
# Processing Record 44 of Set 4 | morondava
# Processing Record 45 of Set 4 | kavieng
# Processing Record 46 of Set 4 | vestmannaeyjar
# Processing Record 47 of Set 4 | labranzagrande
# Processing Record 48 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 49 of Set 4 | bowen
# Processing Record 50 of Set 4 | lafiagi
# Processing Record 1 of Set 5 | ozgon
# City not found. Skipping...
# Processing Record 2 of Set 5 | luderitz
# Processing Record 3 of Set 5 | chalus
# Processing Record 4 of Set 5 | fomboni
# Processing Record 5 of Set 5 | port hardy
# Processing Record 6 of Set 5 | vostok
# Processing Record 7 of Set 5 | sibiti
# Processing Record 8 of Set 5 | groningen
# Processing Record 9 of Set 5 | nanortalik
# Processing Record 10 of Set 5 | labuhan
# Processing Record 11 of Set 5 | mehamn
# Processing Record 12 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 13 of Set 5 | zavitinsk
# Processing Record 14 of Set 5 | sabang
# Processing Record 15 of Set 5 | shahdadpur
# Processing Record 16 of Set 5 | dingle
# Processing Record 17 of Set 5 | simao
# Processing Record 18 of Set 5 | itaobim
# Processing Record 19 of Set 5 | henties bay
# Processing Record 20 of Set 5 | sao borja
# Processing Record 21 of Set 5 | barentu
# Processing Record 22 of Set 5 | nioro
# Processing Record 23 of Set 5 | aripuana
# Processing Record 24 of Set 5 | cockburn town
# Processing Record 25 of Set 5 | onega
# Processing Record 26 of Set 5 | ljubovija
# Processing Record 27 of Set 5 | kauhajoki
# Processing Record 28 of Set 5 | mubende
# Processing Record 29 of Set 5 | faanui
# Processing Record 30 of Set 5 | hambantota
# Processing Record 31 of Set 5 | kadoma
# Processing Record 32 of Set 5 | san matias
# Processing Record 33 of Set 5 | yatou
# Processing Record 34 of Set 5 | port elizabeth
# Processing Record 35 of Set 5 | shimoda
# Processing Record 36 of Set 5 | itarema
# Processing Record 37 of Set 5 | nome
# Processing Record 38 of Set 5 | mocambique
# City not found. Skipping...
# Processing Record 39 of Set 5 | kawalu
# Processing Record 40 of Set 5 | cherskiy
# Processing Record 41 of Set 5 | husavik
# Processing Record 42 of Set 5 | presidencia roque saenz pena
# Processing Record 43 of Set 5 | kahului
# Processing Record 44 of Set 5 | koyilandi
# City not found. Skipping...
# Processing Record 45 of Set 5 | yilan
# Processing Record 46 of Set 5 | la asuncion
# Processing Record 47 of Set 5 | boueni
# Processing Record 48 of Set 5 | talnakh
# Processing Record 49 of Set 5 | estepona
# Processing Record 50 of Set 5 | guerrero negro
# Processing Record 1 of Set 6 | chimbote
# Processing Record 2 of Set 6 | saint-philippe
# Processing Record 3 of Set 6 | parksville
# Processing Record 4 of Set 6 | venado tuerto
# Processing Record 5 of Set 6 | chase
# Processing Record 6 of Set 6 | yerbogachen
# Processing Record 7 of Set 6 | loding
# Processing Record 8 of Set 6 | beitbridge
# Processing Record 9 of Set 6 | norman wells
# Processing Record 10 of Set 6 | khani
# Processing Record 11 of Set 6 | leningradskiy
# Processing Record 12 of Set 6 | kuche
# City not found. Skipping...
# Processing Record 13 of Set 6 | upernavik
# Processing Record 14 of Set 6 | yurginskoye
# Processing Record 15 of Set 6 | dabola
# Processing Record 16 of Set 6 | non sang
# Processing Record 17 of Set 6 | haikou
# Processing Record 18 of Set 6 | quthing
# Processing Record 19 of Set 6 | timra
# Processing Record 20 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 21 of Set 6 | dong hoi
# Processing Record 22 of Set 6 | kotka
# Processing Record 23 of Set 6 | okha
# Processing Record 24 of Set 6 | sechura
# Processing Record 25 of Set 6 | saint anthony
# Processing Record 26 of Set 6 | cabo san lucas
# Processing Record 27 of Set 6 | rio grande
# Processing Record 28 of Set 6 | kudahuvadhoo
# Processing Record 29 of Set 6 | haines junction
# Processing Record 30 of Set 6 | pacifica
# Processing Record 31 of Set 6 | faya
# Processing Record 32 of Set 6 | monte patria
# Processing Record 33 of Set 6 | ambon
# Processing Record 34 of Set 6 | mobaye
# Processing Record 35 of Set 6 | jaciara
# Processing Record 36 of Set 6 | kirakira
# Processing Record 37 of Set 6 | eureka
# Processing Record 38 of Set 6 | isangel
# Processing Record 39 of Set 6 | storforshei
# Processing Record 40 of Set 6 | mandello del lario
# Processing Record 41 of Set 6 | rio muerto
# Processing Record 42 of Set 6 | amapa
# Processing Record 43 of Set 6 | fairbanks
# Processing Record 44 of Set 6 | aklavik
# Processing Record 45 of Set 6 | galiwinku
# City not found. Skipping...
# Processing Record 46 of Set 6 | bourg-en-bresse
# Processing Record 47 of Set 6 | elko
# Processing Record 48 of Set 6 | mitsamiouli
# Processing Record 49 of Set 6 | pizarro
# Processing Record 50 of Set 6 | yeppoon
# Processing Record 1 of Set 7 | fairview
# Processing Record 2 of Set 7 | novonukutskiy
# Processing Record 3 of Set 7 | khonuu
# City not found. Skipping...
# Processing Record 4 of Set 7 | viedma
# Processing Record 5 of Set 7 | vredendal
# Processing Record 6 of Set 7 | svetlogorsk
# Processing Record 7 of Set 7 | svetlaya
# Processing Record 8 of Set 7 | cah ab
# City not found. Skipping...
# Processing Record 9 of Set 7 | turukhansk
# Processing Record 10 of Set 7 | vao
# Processing Record 11 of Set 7 | airai
# Processing Record 12 of Set 7 | abu road
# Processing Record 13 of Set 7 | valparaiso
# Processing Record 14 of Set 7 | banda aceh
# Processing Record 15 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 16 of Set 7 | port alfred
# Processing Record 17 of Set 7 | mayya
# Processing Record 18 of Set 7 | tornio
# Processing Record 19 of Set 7 | odienne
# Processing Record 20 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 21 of Set 7 | te anau
# Processing Record 22 of Set 7 | hilo
# Processing Record 23 of Set 7 | ubrique
# Processing Record 24 of Set 7 | livingston
# Processing Record 25 of Set 7 | zaria
# Processing Record 26 of Set 7 | moreno
# Processing Record 27 of Set 7 | plettenberg bay
# Processing Record 28 of Set 7 | jerome
# Processing Record 29 of Set 7 | luau
# Processing Record 30 of Set 7 | sur
# Processing Record 31 of Set 7 | alice springs
# Processing Record 32 of Set 7 | gorgan
# Processing Record 33 of Set 7 | tupiza
# Processing Record 34 of Set 7 | gambo
# Processing Record 35 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 36 of Set 7 | youkounkoun
# Processing Record 37 of Set 7 | ahuimanu
# Processing Record 38 of Set 7 | benghazi
# Processing Record 39 of Set 7 | sitka
# Processing Record 40 of Set 7 | kirkuk
# Processing Record 41 of Set 7 | bindki
# Processing Record 42 of Set 7 | musoma
# Processing Record 43 of Set 7 | mitu
# Processing Record 44 of Set 7 | elbeuf
# Processing Record 45 of Set 7 | videira
# Processing Record 46 of Set 7 | ossora
# Processing Record 47 of Set 7 | cayenne
# Processing Record 48 of Set 7 | harper
# Processing Record 49 of Set 7 | kitimat
# Processing Record 50 of Set 7 | achisay
# City not found. Skipping...
# Processing Record 1 of Set 8 | tuggurt
# City not found. Skipping...
# Processing Record 2 of Set 8 | betul
# Processing Record 3 of Set 8 | pereslavl-zalesskiy
# Processing Record 4 of Set 8 | nouadhibou
# Processing Record 5 of Set 8 | lagoa
# Processing Record 6 of Set 8 | camacha
# Processing Record 7 of Set 8 | ishinomaki
# Processing Record 8 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 9 of Set 8 | keti bandar
# Processing Record 10 of Set 8 | antsohihy
# Processing Record 11 of Set 8 | watsa
# Processing Record 12 of Set 8 | makakilo city
# Processing Record 13 of Set 8 | southbridge
# Processing Record 14 of Set 8 | cam pha
# City not found. Skipping...
# Processing Record 15 of Set 8 | kazachinskoye
# Processing Record 16 of Set 8 | barra do garcas
# Processing Record 17 of Set 8 | okakarara
# Processing Record 18 of Set 8 | kenai
# Processing Record 19 of Set 8 | havre
# Processing Record 20 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 21 of Set 8 | tommot
# Processing Record 22 of Set 8 | suzun
# Processing Record 23 of Set 8 | tilichiki
# Processing Record 24 of Set 8 | gimli
# Processing Record 25 of Set 8 | mormugao
# Processing Record 26 of Set 8 | angoche
# Processing Record 27 of Set 8 | daru
# Processing Record 28 of Set 8 | collie
# Processing Record 29 of Set 8 | tigil
# Processing Record 30 of Set 8 | abha
# Processing Record 31 of Set 8 | kidal
# Processing Record 32 of Set 8 | kasongo-lunda
# Processing Record 33 of Set 8 | cidreira
# Processing Record 34 of Set 8 | touros
# Processing Record 35 of Set 8 | rawson
# Processing Record 36 of Set 8 | iwanai
# Processing Record 37 of Set 8 | sarangani
# Processing Record 38 of Set 8 | lasa
# Processing Record 39 of Set 8 | batemans bay
# Processing Record 40 of Set 8 | morehead
# Processing Record 41 of Set 8 | yulara
# Processing Record 42 of Set 8 | skelleftea
# Processing Record 43 of Set 8 | waipawa
# Processing Record 44 of Set 8 | zhangjiakou
# Processing Record 45 of Set 8 | chuy
# Processing Record 46 of Set 8 | wellington
# Processing Record 47 of Set 8 | danielskuil
# Processing Record 48 of Set 8 | gayny
# Processing Record 49 of Set 8 | dauphin
# Processing Record 50 of Set 8 | litovko
# Processing Record 1 of Set 9 | sioux lookout
# Processing Record 2 of Set 9 | pochutla
# Processing Record 3 of Set 9 | moranbah
# Processing Record 4 of Set 9 | fernley
# Processing Record 5 of Set 9 | komsomolskiy
# Processing Record 6 of Set 9 | phan rang
# City not found. Skipping...
# Processing Record 7 of Set 9 | sao joao da barra
# Processing Record 8 of Set 9 | esperance
# Processing Record 9 of Set 9 | ruangwa
# Processing Record 10 of Set 9 | tabou
# Processing Record 11 of Set 9 | atbasar
# Processing Record 12 of Set 9 | anchorage
# Processing Record 13 of Set 9 | bac lieu
# Processing Record 14 of Set 9 | kabanjahe
# Processing Record 15 of Set 9 | ust-kuyga
# Processing Record 16 of Set 9 | ahipara
# Processing Record 17 of Set 9 | samarai
# Processing Record 18 of Set 9 | olafsvik
# Processing Record 19 of Set 9 | zhangye
# Processing Record 20 of Set 9 | mazamari
# Processing Record 21 of Set 9 | moundou
# Processing Record 22 of Set 9 | barbar
# City not found. Skipping...
# Processing Record 23 of Set 9 | appenzell
# Processing Record 24 of Set 9 | genc
# Processing Record 25 of Set 9 | gaoyou
# Processing Record 26 of Set 9 | pisco
# Processing Record 27 of Set 9 | bloemfontein
# Processing Record 28 of Set 9 | guane
# Processing Record 29 of Set 9 | selma
# Processing Record 30 of Set 9 | brenham
# Processing Record 31 of Set 9 | los llanos de aridane
# Processing Record 32 of Set 9 | toufen
# Processing Record 33 of Set 9 | vila franca do campo
# Processing Record 34 of Set 9 | bathsheba
# Processing Record 35 of Set 9 | broken hill
# Processing Record 36 of Set 9 | pocatello
# Processing Record 37 of Set 9 | nizhniy odes
# Processing Record 38 of Set 9 | great bend
# Processing Record 39 of Set 9 | bogorodskoye
# Processing Record 40 of Set 9 | bethanien
# Processing Record 41 of Set 9 | sabha
# Processing Record 42 of Set 9 | san luis
# Processing Record 43 of Set 9 | naze
# Processing Record 44 of Set 9 | toliary
# City not found. Skipping...
# Processing Record 45 of Set 9 | arlit
# Processing Record 46 of Set 9 | warwick
# Processing Record 47 of Set 9 | lavrentiya
# Processing Record 48 of Set 9 | carnarvon
# Processing Record 49 of Set 9 | klaksvik
# Processing Record 50 of Set 9 | ayr
# Processing Record 1 of Set 10 | fort nelson
# Processing Record 2 of Set 10 | mineiros
# Processing Record 3 of Set 10 | mount gambier
# Processing Record 4 of Set 10 | lata
# Processing Record 5 of Set 10 | marrakesh
# Processing Record 6 of Set 10 | guangyuan
# Processing Record 7 of Set 10 | kilmez
# City not found. Skipping...
# Processing Record 8 of Set 10 | kenitra
# Processing Record 9 of Set 10 | tezu
# Processing Record 10 of Set 10 | dickinson
# Processing Record 11 of Set 10 | zhigansk
# Processing Record 12 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 13 of Set 10 | lufilufi
# Processing Record 14 of Set 10 | santiago del estero
# Processing Record 15 of Set 10 | mkushi
# Processing Record 16 of Set 10 | nishihara
# Processing Record 17 of Set 10 | skagastrond
# City not found. Skipping...
# Processing Record 18 of Set 10 | sept-iles
# Processing Record 19 of Set 10 | phak hai
# Processing Record 20 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 21 of Set 10 | hualmay
# Processing Record 22 of Set 10 | barcelos
# Processing Record 23 of Set 10 | ugoofaaru
# Processing Record 24 of Set 10 | sohag
# Processing Record 25 of Set 10 | shizunai
# Processing Record 26 of Set 10 | kangaatsiaq
# Processing Record 27 of Set 10 | hofn
# Processing Record 28 of Set 10 | sistranda
# Processing Record 29 of Set 10 | ina
# Processing Record 30 of Set 10 | liminangcong
# City not found. Skipping...
# Processing Record 31 of Set 10 | mandalgovi
# Processing Record 32 of Set 10 | shakawe
# Processing Record 33 of Set 10 | saint simons
# Processing Record 34 of Set 10 | coquimbo
# Processing Record 35 of Set 10 | yelizovo
# Processing Record 36 of Set 10 | sandakan
# Processing Record 37 of Set 10 | bosaso
# Processing Record 38 of Set 10 | eyl
# Processing Record 39 of Set 10 | fort saint john
# City not found. Skipping...
# Processing Record 40 of Set 10 | berdigestyakh
# Processing Record 41 of Set 10 | sinnamary
# Processing Record 42 of Set 10 | beringovskiy
# Processing Record 43 of Set 10 | almeirim
# Processing Record 44 of Set 10 | lompoc
# Processing Record 45 of Set 10 | male
# Processing Record 46 of Set 10 | rach gia
# Processing Record 47 of Set 10 | nantucket
# Processing Record 48 of Set 10 | synya
# Processing Record 49 of Set 10 | yumen
# Processing Record 50 of Set 10 | raudeberg
# Processing Record 1 of Set 11 | otane
# Processing Record 2 of Set 11 | brae
# Processing Record 3 of Set 11 | umea
# Processing Record 4 of Set 11 | sentyabrskiy
# City not found. Skipping...
# Processing Record 5 of Set 11 | mao
# Processing Record 6 of Set 11 | labuan
# Processing Record 7 of Set 11 | griffith
# Processing Record 8 of Set 11 | brigantine
# Processing Record 9 of Set 11 | zarubino
# Processing Record 10 of Set 11 | svetlyy
# Processing Record 11 of Set 11 | taoudenni
# Processing Record 12 of Set 11 | mayo
# Processing Record 13 of Set 11 | bundibugyo
# Processing Record 14 of Set 11 | muncar
# Processing Record 15 of Set 11 | deputatskiy
# Processing Record 16 of Set 11 | kamenka
# Processing Record 17 of Set 11 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 18 of Set 11 | rochester
# Processing Record 19 of Set 11 | shelburne
# Processing Record 20 of Set 11 | boke
# Processing Record 21 of Set 11 | namatanai
# Processing Record 22 of Set 11 | viking
# Processing Record 23 of Set 11 | san jose
# Processing Record 24 of Set 11 | shizuishan
# Processing Record 25 of Set 11 | caiaponia
# Processing Record 26 of Set 11 | sicuani
# Processing Record 27 of Set 11 | kuliyapitiya
# Processing Record 28 of Set 11 | fortuna
# Processing Record 29 of Set 11 | naryan-mar
# Processing Record 30 of Set 11 | copiapo
# Processing Record 31 of Set 11 | arman
# Processing Record 32 of Set 11 | zyryanka
# Processing Record 33 of Set 11 | nicolas bravo
# Processing Record 34 of Set 11 | tautira
# Processing Record 35 of Set 11 | srednekolymsk
# Processing Record 36 of Set 11 | cheltenham
# Processing Record 37 of Set 11 | cassilandia
# Processing Record 38 of Set 11 | sao felix do xingu
# Processing Record 39 of Set 11 | ternate
# Processing Record 40 of Set 11 | pitimbu
# Processing Record 41 of Set 11 | praia da vitoria
# Processing Record 42 of Set 11 | kautokeino
# Processing Record 43 of Set 11 | szendro
# Processing Record 44 of Set 11 | umm kaddadah
# Processing Record 45 of Set 11 | gladstone
# Processing Record 46 of Set 11 | trelew
# Processing Record 47 of Set 11 | jackson
# Processing Record 48 of Set 11 | goure
# Processing Record 49 of Set 11 | chicama
# Processing Record 50 of Set 11 | karkaralinsk
# City not found. Skipping...
# Processing Record 1 of Set 12 | kerema
# Processing Record 2 of Set 12 | opuwo
# Processing Record 3 of Set 12 | solovetskiy
# City not found. Skipping...
# Processing Record 4 of Set 12 | lahij
# Processing Record 5 of Set 12 | chingirlau
# Processing Record 6 of Set 12 | jurm
# Processing Record 7 of Set 12 | itapora
# Processing Record 8 of Set 12 | zhaozhou
# Processing Record 9 of Set 12 | gornopravdinsk
# Processing Record 10 of Set 12 | pirae
# Processing Record 11 of Set 12 | bengkulu
# Processing Record 12 of Set 12 | alofi
# Processing Record 13 of Set 12 | villablino
# Processing Record 14 of Set 12 | palauig
# Processing Record 15 of Set 12 | villa maria
# Processing Record 16 of Set 12 | aksay
# Processing Record 17 of Set 12 | saint-augustin
# Processing Record 18 of Set 12 | sesheke
# Processing Record 19 of Set 12 | erenhot
# Processing Record 20 of Set 12 | port macquarie
# Processing Record 21 of Set 12 | lazaro cardenas
# Processing Record 22 of Set 12 | grindavik
# Processing Record 23 of Set 12 | asau
# Processing Record 24 of Set 12 | tiarei
# Processing Record 25 of Set 12 | matara
# Processing Record 26 of Set 12 | adre
# Processing Record 27 of Set 12 | hami
# Processing Record 28 of Set 12 | hastings
# Processing Record 29 of Set 12 | nelson bay
# Processing Record 30 of Set 12 | ust-nera
# Processing Record 31 of Set 12 | buala
# Processing Record 32 of Set 12 | port blair
# Processing Record 33 of Set 12 | barrie
# Processing Record 34 of Set 12 | bonavista
# Processing Record 35 of Set 12 | palmer
# Processing Record 36 of Set 12 | khormuj
# City not found. Skipping...
# Processing Record 37 of Set 12 | nador
# Processing Record 38 of Set 12 | maragogi
# Processing Record 39 of Set 12 | saint-pierre
# Processing Record 40 of Set 12 | lubumbashi
# Processing Record 41 of Set 12 | uvinza
# Processing Record 42 of Set 12 | kalaleh
# Processing Record 43 of Set 12 | gilgit
# Processing Record 44 of Set 12 | ko samui
# Processing Record 45 of Set 12 | locri
# Processing Record 46 of Set 12 | kyra
# Processing Record 47 of Set 12 | isiro
# Processing Record 48 of Set 12 | tura
# Processing Record 49 of Set 12 | tubruq
# City not found. Skipping...
# Processing Record 50 of Set 12 | poco verde
# Processing Record 1 of Set 13 | luwingu
# Processing Record 2 of Set 13 | cabedelo
# Processing Record 3 of Set 13 | kholmogory
# Processing Record 4 of Set 13 | chichli
# Processing Record 5 of Set 13 | ewa beach
# Processing Record 6 of Set 13 | xinzhou
# Processing Record 7 of Set 13 | iranshahr
# Processing Record 8 of Set 13 | bandrele
# Processing Record 9 of Set 13 | rio pardo de minas
# Processing Record 10 of Set 13 | stantsiya gorchakovo
# City not found. Skipping...
# Processing Record 11 of Set 13 | bantry
# Processing Record 12 of Set 13 | krasnozerskoye
# Processing Record 13 of Set 13 | totolapa
# Processing Record 14 of Set 13 | ola
# Processing Record 15 of Set 13 | san rafael del sur
# Processing Record 16 of Set 13 | mombasa
# Processing Record 17 of Set 13 | bandarbeyla
# Processing Record 18 of Set 13 | staroye drozhzhanoye
# Processing Record 19 of Set 13 | richard toll
# City not found. Skipping...
# Processing Record 20 of Set 13 | mullaitivu
# City not found. Skipping...
# Processing Record 21 of Set 13 | egvekinot
# Processing Record 22 of Set 13 | khorixas
# Processing Record 23 of Set 13 | iisalmi
# Processing Record 24 of Set 13 | filingue
# Processing Record 25 of Set 13 | alausi
# Processing Record 26 of Set 13 | lolua
# City not found. Skipping...
# Processing Record 27 of Set 13 | sao jose da coroa grande
# Processing Record 28 of Set 13 | sun city west
# Processing Record 29 of Set 13 | yanchukan
# City not found. Skipping...
# Processing Record 30 of Set 13 | shugurovo
# Processing Record 31 of Set 13 | carballo
# Processing Record 32 of Set 13 | brokopondo
# Processing Record 33 of Set 13 | quatre cocos
# Processing Record 34 of Set 13 | mollendo
# Processing Record 35 of Set 13 | xuanhua
# Processing Record 36 of Set 13 | tual
# Processing Record 37 of Set 13 | suluq
# Processing Record 38 of Set 13 | kapoeta
# Processing Record 39 of Set 13 | okhotsk
# Processing Record 40 of Set 13 | port arthur
# Processing Record 41 of Set 13 | sorvag
# City not found. Skipping...
# Processing Record 42 of Set 13 | santa barbara
# Processing Record 43 of Set 13 | shingu
# Processing Record 44 of Set 13 | kloulklubed
# Processing Record 45 of Set 13 | jalu
# Processing Record 46 of Set 13 | ankang
# Processing Record 47 of Set 13 | oda
# Processing Record 48 of Set 13 | lima
# Processing Record 49 of Set 13 | terrasini
# Processing Record 50 of Set 13 | takayama
# Processing Record 1 of Set 14 | swellendam
# Processing Record 2 of Set 14 | umm lajj
# Processing Record 3 of Set 14 | acandi
# Processing Record 4 of Set 14 | varzea da palma
# Processing Record 5 of Set 14 | northam
# Processing Record 6 of Set 14 | lena
# Processing Record 7 of Set 14 | yarada
# Processing Record 8 of Set 14 | havre-saint-pierre
# Processing Record 9 of Set 14 | wilmington
# Processing Record 10 of Set 14 | araouane
# Processing Record 11 of Set 14 | esna
# Processing Record 12 of Set 14 | havelock
# Processing Record 13 of Set 14 | bertoua
# Processing Record 14 of Set 14 | sayville
# Processing Record 15 of Set 14 | shaunavon
# Processing Record 16 of Set 14 | linchuan
# City not found. Skipping...
# Processing Record 17 of Set 14 | oyonnax
# Processing Record 18 of Set 14 | rio gallegos
# Processing Record 19 of Set 14 | yukhnov
# Processing Record 20 of Set 14 | north bend
# Processing Record 21 of Set 14 | alta floresta
# Processing Record 22 of Set 14 | bonnyville
# Processing Record 23 of Set 14 | nguiu
# City not found. Skipping...
# Processing Record 24 of Set 14 | bure
# Processing Record 25 of Set 14 | srandakan
# Processing Record 26 of Set 14 | burkhala
# City not found. Skipping...
# Processing Record 27 of Set 14 | ust-tsilma
# Processing Record 28 of Set 14 | katsuura
# Processing Record 29 of Set 14 | izumo
# Processing Record 30 of Set 14 | seymchan
# Processing Record 31 of Set 14 | genhe
# Processing Record 32 of Set 14 | bandar
# Processing Record 33 of Set 14 | broome
# Processing Record 34 of Set 14 | atasu
# Processing Record 35 of Set 14 | idenao
# Processing Record 36 of Set 14 | taybad
# Processing Record 37 of Set 14 | ucluelet
# Processing Record 38 of Set 14 | anito
# Processing Record 39 of Set 14 | chiang klang
# Processing Record 40 of Set 14 | whitehorse
# Processing Record 41 of Set 14 | filadelfia
# Processing Record 42 of Set 14 | pandan
# Processing Record 43 of Set 14 | sobolevo
# Processing Record 44 of Set 14 | sorland
# Processing Record 45 of Set 14 | nampa
# Processing Record 46 of Set 14 | hihifo
# City not found. Skipping...
# Processing Record 47 of Set 14 | port hedland
# Processing Record 48 of Set 14 | banavar
# Processing Record 49 of Set 14 | yuncheng
# Processing Record 50 of Set 14 | margate
# Processing Record 1 of Set 15 | mogadishu
# Processing Record 2 of Set 15 | padilla
# Processing Record 3 of Set 15 | antalaha
# Processing Record 4 of Set 15 | louisbourg
# City not found. Skipping...
# Processing Record 5 of Set 15 | yangzhou
# Processing Record 6 of Set 15 | chapada dos guimaraes
# Processing Record 7 of Set 15 | kilindoni
# Processing Record 8 of Set 15 | mogzon
# Processing Record 9 of Set 15 | coahuayana
# Processing Record 10 of Set 15 | opotiki
# Processing Record 11 of Set 15 | mayor pablo lagerenza
# Processing Record 12 of Set 15 | birjand
# Processing Record 13 of Set 15 | eaglesham
# Processing Record 14 of Set 15 | chalisgaon
# Processing Record 15 of Set 15 | inuvik
# Processing Record 16 of Set 15 | kogon
# Processing Record 17 of Set 15 | oksovskiy
# Processing Record 18 of Set 15 | anzhero-sudzhensk
# Processing Record 19 of Set 15 | paramonga
# Processing Record 20 of Set 15 | kariapatti
# Processing Record 21 of Set 15 | victor harbor
# Processing Record 22 of Set 15 | ipixuna
# Processing Record 23 of Set 15 | najran
# Processing Record 24 of Set 15 | padang
# Processing Record 25 of Set 15 | rock sound
# Processing Record 26 of Set 15 | gat
# Processing Record 27 of Set 15 | krasnotorka
# Processing Record 28 of Set 15 | lipetsk
# Processing Record 29 of Set 15 | bani
# Processing Record 30 of Set 15 | san pedro
# Processing Record 31 of Set 15 | kungurtug
# Processing Record 32 of Set 15 | bridgetown
# Processing Record 33 of Set 15 | xai-xai
# Processing Record 34 of Set 15 | rena
# Processing Record 35 of Set 15 | coalinga
# Processing Record 36 of Set 15 | seoul
# Processing Record 37 of Set 15 | mocuba
# Processing Record 38 of Set 15 | falam
# Processing Record 39 of Set 15 | vilhena
# Processing Record 40 of Set 15 | wurzen
# Processing Record 41 of Set 15 | marica
# Processing Record 42 of Set 15 | la ronge
# Processing Record 43 of Set 15 | tessalit
# Processing Record 44 of Set 15 | derzhavinsk
# Processing Record 45 of Set 15 | charters towers
# Processing Record 46 of Set 15 | sisimiut
# Processing Record 47 of Set 15 | parabel
# Processing Record 48 of Set 15 | fare
# Processing Record 49 of Set 15 | netanya
# Processing Record 50 of Set 15 | sahrak
# City not found. Skipping...
# Processing Record 1 of Set 16 | epe
# Processing Record 2 of Set 16 | zolotinka
# City not found. Skipping...
# Processing Record 3 of Set 16 | oyama
# Processing Record 4 of Set 16 | parana
# Processing Record 5 of Set 16 | aracruz
# Processing Record 6 of Set 16 | khromtau
# Processing Record 7 of Set 16 | zarand
# Processing Record 8 of Set 16 | acajutla
# Processing Record 9 of Set 16 | aykhal
# Processing Record 10 of Set 16 | fukue
# Processing Record 11 of Set 16 | upata
# ----------------------------------
# Date Retrival Complete
# ----------------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Bluff -46.6000  168.3333      9.89        92          97
# 1        Juneau  58.3019 -134.4197     12.34        97         100
# 2  Saint George  37.1041 -113.5841     21.55        31           0
# 3  Punta Arenas -53.1500  -70.9167      9.06        49          40
# 4     Geraldton -28.7667  114.6000     11.23        87           0
# 5  Kruisfontein -34.0033   24.7314     18.82        83          92
# 6       Mataura -46.1927  168.8643      9.71        99         100
# 7   Tuktoyaktuk  69.4541 -133.0374     -1.00        93         100
# 8        Albany  42.6001  -73.9662     17.19        74          96
# 9     Jamestown  42.0970  -79.2353     15.57        75         100
#
#    Wind Speed Country Current Description
# 0        1.96      NZ     overcast clouds
# 1        4.12      US     overcast clouds
# 2        2.57      US           clear sky
# 3       10.29      CL    scattered clouds
# 4        4.12      AU           clear sky
# 5        4.64      ZA     overcast clouds
# 6        0.45      NZ     overcast clouds
# 7        4.12      CA          light snow
# 8        0.89      US     overcast clouds
# 9        4.47      US          light rain

# %%
new_coulumn_order = ['City','Country','Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness','Wind Speed', 'Current Description']
city_data_df = city_data_df[new_coulumn_order]
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Bluff      NZ -46.6000  168.3333      9.89        92          97
# 1        Juneau      US  58.3019 -134.4197     12.34        97         100
# 2  Saint George      US  37.1041 -113.5841     21.55        31           0
# 3  Punta Arenas      CL -53.1500  -70.9167      9.06        49          40
# 4     Geraldton      AU -28.7667  114.6000     11.23        87           0
# 5  Kruisfontein      ZA -34.0033   24.7314     18.82        83          92
# 6       Mataura      NZ -46.1927  168.8643      9.71        99         100
# 7   Tuktoyaktuk      CA  69.4541 -133.0374     -1.00        93         100
# 8        Albany      US  42.6001  -73.9662     17.19        74          96
# 9     Jamestown      US  42.0970  -79.2353     15.57        75         100
#
#    Wind Speed Current Description
# 0        1.96     overcast clouds
# 1        4.12     overcast clouds
# 2        2.57           clear sky
# 3       10.29    scattered clouds
# 4        4.12           clear sky
# 5        4.64     overcast clouds
# 6        0.45     overcast clouds
# 7        4.12          light snow
# 8        0.89     overcast clouds
# 9        4.47          light rain

# %%
# Create the output file (CSV)
output_data_file = '../Weather_Database/WeatherPy_Database.csv'

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label='City_ID')
